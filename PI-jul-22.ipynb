# %% [markdown]
# # Analyse Descriptive de fichier jul-22

# %%
import pandas as pd

# %%
df1 = pd.read_excel("C:/Users/hp/Downloads/projet/jul-22.xlsx",keep_default_na=True, header=0)

# %%
df1.columns
# Out:
# Index(['co_id', 'activation_date', 'total_nb_recharge', 'total_rechage',
#        'total_u_data', 'total_rev_option', 'total_rev_sos', 'total_u_out',
#        'total_u_in', 'usage_op1', 'usage_op2', 'usage_op3', 'nb_cont_out',
#        'nb_cont_in', 'nb_cell_visite_out', 'nb_cell_visite_in', 'entity_code',
#        'entity_type_name', 'nbr_contrat', 'nbr_actif', 'flag_churn'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266737 entries, 0 to 266736
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   co_id               266736 non-null  float64
#  1   activation_date     266736 non-null  object
#  2   total_nb_recharge   237988 non-null  float64
#  3   total_rechage       237988 non-null  float64
#  4   total_u_data        219471 non-null  float64
#  5   total_rev_option    157812 non-null  float64
#  6   total_rev_sos       407 non-null     float64
#  7   total_u_out         246603 non-null  float64
#  8   total_u_in          187019 non-null  float64
#  9   usage_op1           1429 non-null    float64
#  10  usage_op2           19874 non-null   float64
#  11  usage_op3           158667 non-null  float64
#  12  nb_cont_out         245387 non-null  float64
#  13  nb_cont_in          253465 non-null  float64
#  14  nb_cell_visite_out  245387 non-null  float64
# ...

# %%
df1.dtypes
# Out:
# co_id                 float64
# activation_date        object
# total_nb_recharge     float64
# total_rechage         float64
# total_u_data          float64
# total_rev_option      float64
# total_rev_sos         float64
# total_u_out           float64
# total_u_in            float64
# usage_op1             float64
# usage_op2             float64
# usage_op3             float64
# nb_cont_out           float64
# nb_cont_in            float64
# nb_cell_visite_out    float64
# nb_cell_visite_in     float64
# entity_code            object
# entity_type_name       object
# nbr_contrat           float64
# nbr_actif             float64
# flag_churn            float64
# dtype: object

# %%
df1.head()
# Out:
#         co_id      activation_date  total_nb_recharge  total_rechage  \
# 0  36799963.0  2022-07-20 19:45:16                2.0          1.878
# 1  36800104.0  2022-07-20 10:39:24                1.0          0.878
# 2  34763697.0  2022-07-06 13:27:15               25.0         28.386
# 3  36822172.0  2022-07-17 11:47:54                1.0          0.878
# 4  34745291.0  2022-07-04 11:13:53                1.0          4.386
#
#    total_u_data  total_rev_option  total_rev_sos  total_u_out  total_u_in  \
# 0  1.089560e+07          0.756302            NaN       14.950       0.633
# 1  9.520800e+06               NaN            NaN       14.983      17.617
# 2  8.024546e+06         11.428571            NaN      240.100      86.034
# 3  6.366023e+06               NaN            NaN       13.083       4.183
# 4  2.587891e-01               NaN            NaN        1.967       5.784
#
#    usage_op1  ...  usage_op3  nb_cont_out  nb_cont_in  nb_cell_visite_out  \
# ...

# %%
df1.tail()
# Out:
#              co_id      activation_date  total_nb_recharge  total_rechage  \
# 266732  29301874.0  2022-07-31 01:32:57                NaN            NaN
# 266733  38299066.0  2022-07-04 14:02:05                2.0         13.158
# 266734  34746344.0  2022-07-08 10:39:33               14.0         18.264
# 266735  37837851.0  2022-07-17 21:31:35                NaN            NaN
# 266736         NaN                  NaN                NaN            NaN
#
#         total_u_data  total_rev_option  total_rev_sos  total_u_out  \
# 266732  7.736420e+06          5.042017            NaN     1238.483
# 266733           NaN               NaN            NaN      433.499
# 266734  7.551181e+06         12.941176            NaN       47.750
# 266735  1.240820e+03               NaN            NaN        0.000
# 266736           NaN               NaN            NaN          NaN
#
#         total_u_in  usage_op1  ...  usage_op3  nb_cont_out  nb_cont_in  \
# ...

# %%
df1.describe()
# Out:
#               co_id  total_nb_recharge  total_rechage  total_u_data  \
# count  2.667360e+05      237988.000000  237988.000000  2.194710e+05
# mean   3.801739e+07           3.894083      16.415643  6.716725e+06
# std    1.269256e+06           5.512620      21.539708  1.455476e+07
# min    6.162140e+05           1.000000       0.000000  3.906250e-02
# 25%    3.793612e+07           1.000000       2.000000  4.961247e+05
# 50%    3.833921e+07           2.000000       7.755000  1.851783e+06
# 75%    3.847398e+07           4.000000      25.000000  6.585594e+06
# max    3.882578e+07         157.000000    1591.580002  9.472272e+08
#
#        total_rev_option  total_rev_sos    total_u_out     total_u_in  \
# count     157812.000000     407.000000  246603.000000  187019.000000
# mean          15.543914       3.367014      52.254704      40.297342
# std           16.358311       6.681828     122.879846     119.371431
# min            0.000000       0.084034       0.000000       0.000000
# ...
